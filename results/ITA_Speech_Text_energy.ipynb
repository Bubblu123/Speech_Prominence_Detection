# %%
import numpy as np
import pandas as pd

# %%
df_train=np.load('/content/drive/MyDrive/Speech_text/ITA_train_e.npy')

# %%
df_train.shape
# Out:
# (3444, 256)

# %%
train_labels=np.load('/content/drive/MyDrive/Speech_text/ITA_train_labels.npy')

# %%
train_labels.shape
# Out:
# (3444,)

# %%
df_test=np.load('/content/drive/MyDrive/Speech_text/ITA_test_e.npy')

# %%
df_test.shape
# Out:
# (1301, 256)

# %%
test_labels=np.load('/content/drive/MyDrive/Speech_text/ITA_test_labels.npy')

# %%
test_labels.shape
# Out:
# (1301,)

# %%
df_combined = np.concatenate([df_train, df_test], axis=0)


labels_combined = np.concatenate([train_labels, test_labels], axis=0)

# %%
df_combined.shape
# Out:
# (4745, 256)

# %%
labels_combined.shape
# Out:
# (4745,)

# %% [markdown]
# #38%

# %%
np.unique(labels_combined,return_counts=True)
# Out:
# (array([0, 1]), array([2939, 1806]))

# %%
import numpy as np
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# Perform PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(df_combined)


sns.scatterplot(x=pca_result[:, 0], y=pca_result[:, 1], hue=labels_combined)
plt.title('PCA')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(title='Labels')
plt.show()

# %%
 def convert_cluster_labels(cluster_labels, ground_truth_labels):
            unique_clusters = np.unique(cluster_labels)
            num_clusters = len(unique_clusters)
            num_classes = len(np.unique(ground_truth_labels))

            # Create a mapping between cluster labels and ground truth labels
            label_mapping = {}
            for cluster_label in unique_clusters:
                mask = (cluster_labels == cluster_label)
                assigned_labels = ground_truth_labels[mask]
                # print(assigned_labels)
                unique_assigned_labels, counts = np.unique(assigned_labels, return_counts=True)
                # print(unique_assigned_labels)
                # print(counts)
                mapped_label = unique_assigned_labels[np.argmax(counts)]
                label_mapping[cluster_label] = mapped_label

            # Convert cluster labels to ground truth labels
            converted_labels = np.zeros_like(cluster_labels)
            for cluster_label, mapped_label in label_mapping.items():
                converted_labels[cluster_labels == cluster_label] = mapped_label

            return converted_labels

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import classification_report


n_clusters = 2
kmeans = KMeans(n_clusters=n_clusters, random_state=0)
kmeans.fit(df_train)
cluster_labels = kmeans.predict(df_test)

print(classification_report(test_labels, cluster_labels))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80       764
#            1       1.00      0.29      0.45       537
#
#     accuracy                           0.71      1301
#    macro avg       0.83      0.65      0.63      1301
# weighted avg       0.81      0.71      0.66      1301

# %%
np.unique(cluster_labels,return_counts=True)
# Out:
# (array([0, 1], dtype=int32), array([1143,  158]))

# %%
new_labels=convert_cluster_labels(cluster_labels,test_labels)

# %%
np.unique(new_labels,return_counts=True)
# Out:
# (array([0, 1], dtype=int32), array([1143,  158]))

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import classification_report


n_clusters = 2
kmeans = KMeans(n_clusters=n_clusters, random_state=0)
kmeans.fit(df_train)
cluster_labels = kmeans.predict(df_test)

print(classification_report(test_labels, new_labels))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80       764
#            1       1.00      0.29      0.45       537
#
#     accuracy                           0.71      1301
#    macro avg       0.83      0.65      0.63      1301
# weighted avg       0.81      0.71      0.66      1301

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping

# %%
from keras.optimizers import Adam

model = Sequential([
    Dense(64, activation='relu', input_shape=(256,)),
    BatchNormalization(),
    Dropout(0.3),
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(4, activation='relu'),
    Dense(1, activation='sigmoid')
])


model.compile(optimizer=Adam(learning_rate=1e-3),
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.summary()
# Define callbacks
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                16448
#
#  batch_normalization (Batch  (None, 64)                256
#  Normalization)
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  batch_normalization_1 (Bat  (None, 32)                128
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dense_3 (Dense)             (None, 8)                 136
#
#  dense_4 (Dense)             (None, 4)                 36
#
#  dense_5 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 19617 (76.63 KB)
# Trainable params: 19425 (75.88 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________

# %%
df_train.shape
# Out:
# (3444, 256)

# %%
train_labels.shape
# Out:
# (3444,)

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(df_train,
train_labels,
                    epochs=200,
                    batch_size=32,
                    validation_split=0.2,
                    verbose=1,
                    callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 87/87 [==============================] - 3s 7ms/step - loss: 0.5570 - accuracy: 0.6294 - val_loss: 0.6889 - val_accuracy: 0.6589
# Epoch 2/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3028 - accuracy: 0.8726 - val_loss: 0.7060 - val_accuracy: 0.3411
# Epoch 3/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2682 - accuracy: 0.9815 - val_loss: 0.7130 - val_accuracy: 0.3701
# Epoch 4/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2256 - accuracy: 0.9829 - val_loss: 0.5656 - val_accuracy: 0.6241
# Epoch 5/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.0586 - accuracy: 0.9844 - val_loss: 0.8401 - val_accuracy: 0.7126
# Epoch 6/200
# 87/87 [==============================] - 0s 3ms/step - loss: 0.0358 - accuracy: 0.9866 - val_loss: 0.3368 - val_accuracy: 0.8665
# Epoch 7/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.0318 - accuracy: 0.9887 - val_loss: 0.4465 - val_accuracy: 0.8563
# Epoch 8/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.0132 - accuracy: 0.9978 - val_loss: 0.3609 - val_accuracy: 0.8781
# Epoch 9/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.0386 - accuracy: 0.9858 - val_loss: 0.2724 - val_accuracy: 0.8955
# Epoch 10/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.0179 - accuracy: 0.9949 - val_loss: 0.2727 - val_accuracy: 0.8882
# Epoch 11/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.0350 - accuracy: 0.9884 - val_loss: 0.2614 - val_accuracy: 0.8999
# Epoch 12/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.0338 - accuracy: 0.9891 - val_loss: 0.2257 - val_accuracy: 0.9057
# Epoch 13/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.0295 - accuracy: 0.9895 - val_loss: 0.2590 - val_accuracy: 0.9086
# Epoch 14/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.0186 - accuracy: 0.9942 - val_loss: 0.2337 - val_accuracy: 0.9144
# Epoch 15/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.0291 - accuracy: 0.9898 - val_loss: 0.2344 - val_accuracy: 0.9129
# Epoch 16/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.0233 - accuracy: 0.9927 - val_loss: 0.2474 - val_accuracy: 0.9144
# Epoch 17/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.0177 - accuracy: 0.9931 - val_loss: 0.2489 - val_accuracy: 0.9115
# Epoch 18/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.0188 - accuracy: 0.9931 - val_loss: 0.2994 - val_accuracy: 0.9129
# Epoch 19/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.0236 - accuracy: 0.9913 - val_loss: 0.2913 - val_accuracy: 0.9057
# Epoch 20/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.0117 - accuracy: 0.9949 - val_loss: 0.2970 - val_accuracy: 0.9115
# Epoch 21/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.0232 - accuracy: 0.9909 - val_loss: 0.2482 - val_accuracy: 0.9115
# Epoch 22/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.0247 - accuracy: 0.9920 - val_loss: 0.2736 - val_accuracy: 0.9086

# %%
test_loss, test_acc = model.evaluate(df_test,test_labels)

print('Test accuracy:', test_acc)
# Out:
# 41/41 [==============================] - 0s 2ms/step - loss: 1.1988 - accuracy: 0.7379
# Test accuracy: 0.7378939390182495
