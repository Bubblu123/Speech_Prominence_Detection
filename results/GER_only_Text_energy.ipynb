# %%
import numpy as np
import pandas as pd

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
df_train=np.load('/content/drive/MyDrive/only_text/GER_train_e.npy')

# %%
df_train.shape
# Out:
# (3787, 256)

# %%
train_labels=np.load('/content/drive/MyDrive/only_text/GER_train_labels.npy')

# %%
train_labels.shape
# Out:
# (3787,)

# %%
df_test=np.load('/content/drive/MyDrive/only_text/GER_test_e.npy')

# %%
df_test.shape
# Out:
# (1400, 256)

# %%
test_labels=np.load('/content/drive/MyDrive/only_text/GER_test_labels.npy')

# %%
test_labels.shape
# Out:
# (1400,)

# %%
df_combined = np.concatenate([df_train, df_test], axis=0)


labels_combined = np.concatenate([train_labels, test_labels], axis=0)

# %%
df_combined.shape
# Out:
# (5187, 256)

# %%
labels_combined.shape
# Out:
# (5187,)

# %% [markdown]
# #19%

# %%
np.unique(labels_combined,return_counts=True)
# Out:
# (array([0, 1]), array([4188,  999]))

# %%
import numpy as np
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# Perform PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(df_combined)


sns.scatterplot(x=pca_result[:, 0], y=pca_result[:, 1], hue=labels_combined)
plt.title('PCA')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(title='Labels')
plt.show()

# %%
 def convert_cluster_labels(cluster_labels, ground_truth_labels):
            unique_clusters = np.unique(cluster_labels)
            num_clusters = len(unique_clusters)
            num_classes = len(np.unique(ground_truth_labels))

            # Create a mapping between cluster labels and ground truth labels
            label_mapping = {}
            for cluster_label in unique_clusters:
                mask = (cluster_labels == cluster_label)
                assigned_labels = ground_truth_labels[mask]
                # print(assigned_labels)
                unique_assigned_labels, counts = np.unique(assigned_labels, return_counts=True)
                # print(unique_assigned_labels)
                # print(counts)
                mapped_label = unique_assigned_labels[np.argmax(counts)]
                label_mapping[cluster_label] = mapped_label

            # Convert cluster labels to ground truth labels
            converted_labels = np.zeros_like(cluster_labels)
            for cluster_label, mapped_label in label_mapping.items():
                converted_labels[cluster_labels == cluster_label] = mapped_label

            return converted_labels

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import classification_report


n_clusters = 2
kmeans = KMeans(n_clusters=n_clusters, random_state=0)
kmeans.fit(df_train)
cluster_labels = kmeans.predict(df_test)

print(classification_report(test_labels, cluster_labels))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.95      0.52      0.67      1095
#            1       0.34      0.90      0.50       305
#
#     accuracy                           0.60      1400
#    macro avg       0.65      0.71      0.58      1400
# weighted avg       0.82      0.60      0.63      1400

# %%
np.unique(cluster_labels,return_counts=True)
# Out:
# (array([0, 1], dtype=int32), array([593, 807]))

# %%
new_labels=convert_cluster_labels(cluster_labels,test_labels)

# %%
np.unique(new_labels,return_counts=True)
# Out:
# (array([0], dtype=int32), array([1400]))

# %%
# from sklearn.cluster import KMeans
# from sklearn.metrics import classification_report


# n_clusters = 2
# kmeans = KMeans(n_clusters=n_clusters, random_state=0)
# kmeans.fit(df_train)
# cluster_labels = kmeans.predict(df_test)

# print(classification_report(test_labels, new_labels))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping

# %%
from keras.optimizers import Adam

model = Sequential([
    Dense(64, activation='relu', input_shape=(256,)),
    BatchNormalization(),
    Dropout(0.3),
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(4, activation='relu'),
    Dense(1, activation='sigmoid')
])


model.compile(optimizer=Adam(learning_rate=1e-3),
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.summary()
# Define callbacks
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                16448
#
#  batch_normalization (Batch  (None, 64)                256
#  Normalization)
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  batch_normalization_1 (Bat  (None, 32)                128
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dense_3 (Dense)             (None, 8)                 136
#
#  dense_4 (Dense)             (None, 4)                 36
#
#  dense_5 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 19617 (76.63 KB)
# Trainable params: 19425 (75.88 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________

# %%
df_train.shape
# Out:
# (3787, 256)

# %%
train_labels.shape
# Out:
# (3787,)

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(df_train,
train_labels,
                    epochs=200,
                    batch_size=32,
                    validation_split=0.2,
                    verbose=1,
                    callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 95/95 [==============================] - 3s 7ms/step - loss: 0.6027 - accuracy: 0.6784 - val_loss: 0.6516 - val_accuracy: 0.8113
# Epoch 2/200
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4216 - accuracy: 0.8188 - val_loss: 0.6834 - val_accuracy: 0.6161
# Epoch 3/200
# 95/95 [==============================] - 0s 5ms/step - loss: 0.3535 - accuracy: 0.8379 - val_loss: 0.8716 - val_accuracy: 0.2058
# Epoch 4/200
# 95/95 [==============================] - 1s 6ms/step - loss: 0.3019 - accuracy: 0.8805 - val_loss: 1.0708 - val_accuracy: 0.3193
# Epoch 5/200
# 95/95 [==============================] - 1s 6ms/step - loss: 0.2749 - accuracy: 0.8854 - val_loss: 0.8326 - val_accuracy: 0.4974
# Epoch 6/200
# 95/95 [==============================] - 1s 6ms/step - loss: 0.2625 - accuracy: 0.8980 - val_loss: 0.9121 - val_accuracy: 0.5000
# Epoch 7/200
# 95/95 [==============================] - 1s 6ms/step - loss: 0.2448 - accuracy: 0.9049 - val_loss: 0.7997 - val_accuracy: 0.6266
# Epoch 8/200
# 95/95 [==============================] - 1s 6ms/step - loss: 0.2367 - accuracy: 0.9062 - val_loss: 0.5080 - val_accuracy: 0.7401
# Epoch 9/200
# 95/95 [==============================] - 1s 6ms/step - loss: 0.2281 - accuracy: 0.9082 - val_loss: 0.4120 - val_accuracy: 0.8140
# Epoch 10/200
# 95/95 [==============================] - 0s 4ms/step - loss: 0.2299 - accuracy: 0.9102 - val_loss: 0.3627 - val_accuracy: 0.8483
# Epoch 11/200
# 95/95 [==============================] - 0s 4ms/step - loss: 0.2248 - accuracy: 0.9138 - val_loss: 0.3860 - val_accuracy: 0.8298
# Epoch 12/200
# 95/95 [==============================] - 0s 4ms/step - loss: 0.2159 - accuracy: 0.9132 - val_loss: 0.4634 - val_accuracy: 0.7902
# Epoch 13/200
# 95/95 [==============================] - 0s 4ms/step - loss: 0.2034 - accuracy: 0.9188 - val_loss: 0.3287 - val_accuracy: 0.8734
# Epoch 14/200
# 95/95 [==============================] - 0s 4ms/step - loss: 0.2107 - accuracy: 0.9155 - val_loss: 0.3818 - val_accuracy: 0.8364
# Epoch 15/200
# 95/95 [==============================] - 0s 4ms/step - loss: 0.2069 - accuracy: 0.9155 - val_loss: 0.3477 - val_accuracy: 0.8628
# Epoch 16/200
# 95/95 [==============================] - 0s 4ms/step - loss: 0.1967 - accuracy: 0.9251 - val_loss: 0.3755 - val_accuracy: 0.8588
# Epoch 17/200
# 95/95 [==============================] - 0s 4ms/step - loss: 0.1990 - accuracy: 0.9194 - val_loss: 0.4242 - val_accuracy: 0.8443
# Epoch 18/200
# 95/95 [==============================] - 0s 4ms/step - loss: 0.1898 - accuracy: 0.9204 - val_loss: 0.3879 - val_accuracy: 0.8496
# Epoch 19/200
# 95/95 [==============================] - 0s 4ms/step - loss: 0.1774 - accuracy: 0.9264 - val_loss: 0.3474 - val_accuracy: 0.8747
# Epoch 20/200
# 95/95 [==============================] - 0s 4ms/step - loss: 0.1704 - accuracy: 0.9274 - val_loss: 0.3821 - val_accuracy: 0.8747
# Epoch 21/200
# 95/95 [==============================] - 0s 4ms/step - loss: 0.1620 - accuracy: 0.9346 - val_loss: 0.3857 - val_accuracy: 0.8641
# Epoch 22/200
# 95/95 [==============================] - 0s 4ms/step - loss: 0.1712 - accuracy: 0.9327 - val_loss: 0.3968 - val_accuracy: 0.8549
# Epoch 23/200
# 95/95 [==============================] - 0s 4ms/step - loss: 0.1661 - accuracy: 0.9310 - val_loss: 0.4237 - val_accuracy: 0.8602

# %%
test_loss, test_acc = model.evaluate(df_test,test_labels)

print('Test accuracy:', test_acc)
# Out:
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3601 - accuracy: 0.8943
# Test accuracy: 0.8942857384681702
