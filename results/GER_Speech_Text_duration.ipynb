# %%
import numpy as np
import pandas as pd

# %%
df_train=np.load('/content/drive/MyDrive/Speech_text/GER_train_d.npy')

# %%
df_train.shape
# Out:
# (3787, 256)

# %%
train_labels=np.load('/content/drive/MyDrive/Speech_text/GER_train_labels.npy')

# %%
train_labels.shape
# Out:
# (3787,)

# %%
df_test=np.load('/content/drive/MyDrive/Speech_text/GER_test_d.npy')

# %%
df_test.shape
# Out:
# (1400, 256)

# %%
test_labels=np.load('/content/drive/MyDrive/Speech_text/GER_test_labels.npy')

# %%
test_labels.shape
# Out:
# (1400,)

# %%
df_combined = np.concatenate([df_train, df_test], axis=0)


labels_combined = np.concatenate([train_labels, test_labels], axis=0)

# %%
df_combined.shape
# Out:
# (5187, 256)

# %%
labels_combined.shape
# Out:
# (5187,)

# %% [markdown]
# #19.2 %

# %%
np.unique(labels_combined,return_counts=True)
# Out:
# (array([0, 1]), array([4188,  999]))

# %%
import numpy as np
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# Perform PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(df_combined)


sns.scatterplot(x=pca_result[:, 0], y=pca_result[:, 1], hue=labels_combined)
plt.title('PCA')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(title='Labels')
plt.show()

# %%
 def convert_cluster_labels(cluster_labels, ground_truth_labels):
            unique_clusters = np.unique(cluster_labels)
            num_clusters = len(unique_clusters)
            num_classes = len(np.unique(ground_truth_labels))
+
            # Create a mapping between cluster labels and ground truth labels
            label_mapping = {}
            for cluster_label in unique_clusters:
                mask = (cluster_labels == cluster_label)
                assigned_labels = ground_truth_labels[mask]
                # print(assigned_labels)
                unique_assigned_labels, counts = np.unique(assigned_labels, return_counts=True)
                # print(unique_assigned_labels)
                # print(counts)
                mapped_label = unique_assigned_labels[np.argmax(counts)]
                label_mapping[cluster_label] = mapped_label

            # Convert cluster labels to ground truth labels
            converted_labels = np.zeros_like(cluster_labels)
            for cluster_label, mapped_label in label_mapping.items():
                converted_labels[cluster_labels == cluster_label] = mapped_label

            return converted_labels

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import classification_report


n_clusters = 2
kmeans = KMeans(n_clusters=n_clusters, random_state=0)
kmeans.fit(df_train)
cluster_labels = kmeans.predict(df_test)

print(classification_report(test_labels, cluster_labels))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.32      0.12      0.18      1095
#            1       0.01      0.03      0.02       305
#
#     accuracy                           0.10      1400
#    macro avg       0.16      0.08      0.10      1400
# weighted avg       0.25      0.10      0.14      1400

# %%
np.unique(cluster_labels,return_counts=True)
# Out:
# (array([0, 1], dtype=int32), array([431, 969]))

# %%
new_labels=convert_cluster_labels(cluster_labels,test_labels)

# %%
np.unique(new_labels,return_counts=True)
# Out:
# (array([0, 1], dtype=int32), array([969, 431]))

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import classification_report


n_clusters = 2
kmeans = KMeans(n_clusters=n_clusters, random_state=0)
kmeans.fit(df_train)
cluster_labels = kmeans.predict(df_test)

print(classification_report(test_labels, new_labels))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.99      0.88      0.93      1095
#            1       0.68      0.97      0.80       305
#
#     accuracy                           0.90      1400
#    macro avg       0.84      0.92      0.87      1400
# weighted avg       0.92      0.90      0.90      1400

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping

# %%
from keras.optimizers import Adam

model = Sequential([
    Dense(64, activation='relu', input_shape=(256,)),
    BatchNormalization(),
    Dropout(0.3),
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(4, activation='relu'),
    Dense(1, activation='sigmoid')
])


model.compile(optimizer=Adam(learning_rate=1e-3),
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.summary()
# Define callbacks
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 64)                16448
#
#  batch_normalization_8 (Bat  (None, 64)                256
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_25 (Dense)            (None, 32)                2080
#
#  batch_normalization_9 (Bat  (None, 32)                128
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 32)                0
#
#  dense_26 (Dense)            (None, 16)                528
#
#  dense_27 (Dense)            (None, 8)                 136
#
#  dense_28 (Dense)            (None, 4)                 36
#
#  dense_29 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 19617 (76.63 KB)
# Trainable params: 19425 (75.88 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(df_train,
train_labels,
                    epochs=200,
                    batch_size=32,
                    validation_split=0.2,
                    verbose=1,
                    callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 95/95 [==============================] - 4s 15ms/step - loss: 0.5413 - accuracy: 0.7854 - val_loss: 0.6791 - val_accuracy: 0.6544
# Epoch 2/200
# 95/95 [==============================] - 0s 4ms/step - loss: 0.2299 - accuracy: 0.9115 - val_loss: 2.7067 - val_accuracy: 0.1900
# Epoch 3/200
# 95/95 [==============================] - 0s 4ms/step - loss: 0.1178 - accuracy: 0.9604 - val_loss: 2.8524 - val_accuracy: 0.1926
# Epoch 4/200
# 95/95 [==============================] - 0s 4ms/step - loss: 0.0983 - accuracy: 0.9647 - val_loss: 1.5522 - val_accuracy: 0.3813
# Epoch 5/200
# 95/95 [==============================] - 1s 6ms/step - loss: 0.0857 - accuracy: 0.9663 - val_loss: 0.7194 - val_accuracy: 0.7203
# Epoch 6/200
# 95/95 [==============================] - 1s 6ms/step - loss: 0.0766 - accuracy: 0.9726 - val_loss: 0.6511 - val_accuracy: 0.7520
# Epoch 7/200
# 95/95 [==============================] - 1s 6ms/step - loss: 0.0709 - accuracy: 0.9742 - val_loss: 0.5182 - val_accuracy: 0.8140
# Epoch 8/200
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0666 - accuracy: 0.9759 - val_loss: 0.4707 - val_accuracy: 0.8325
# Epoch 9/200
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0624 - accuracy: 0.9779 - val_loss: 0.5051 - val_accuracy: 0.8311
# Epoch 10/200
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0580 - accuracy: 0.9805 - val_loss: 0.5685 - val_accuracy: 0.8193
# Epoch 11/200
# 95/95 [==============================] - 0s 5ms/step - loss: 0.0588 - accuracy: 0.9802 - val_loss: 0.4267 - val_accuracy: 0.8588
# Epoch 12/200
# 95/95 [==============================] - 0s 4ms/step - loss: 0.0568 - accuracy: 0.9779 - val_loss: 0.4394 - val_accuracy: 0.8522
# Epoch 13/200
# 95/95 [==============================] - 0s 4ms/step - loss: 0.0614 - accuracy: 0.9769 - val_loss: 0.4780 - val_accuracy: 0.8496
# Epoch 14/200
# 95/95 [==============================] - 0s 4ms/step - loss: 0.0518 - accuracy: 0.9832 - val_loss: 0.5012 - val_accuracy: 0.8391
# Epoch 15/200
# 95/95 [==============================] - 0s 4ms/step - loss: 0.0576 - accuracy: 0.9785 - val_loss: 0.5042 - val_accuracy: 0.8391
# Epoch 16/200
# 95/95 [==============================] - 0s 4ms/step - loss: 0.0573 - accuracy: 0.9825 - val_loss: 0.4218 - val_accuracy: 0.8562
# Epoch 17/200
# 95/95 [==============================] - 0s 4ms/step - loss: 0.0475 - accuracy: 0.9832 - val_loss: 0.4691 - val_accuracy: 0.8549
# Epoch 18/200
# 95/95 [==============================] - 1s 5ms/step - loss: 0.0347 - accuracy: 0.9878 - val_loss: 0.4632 - val_accuracy: 0.8654
# Epoch 19/200
# 95/95 [==============================] - 1s 6ms/step - loss: 0.0474 - accuracy: 0.9842 - val_loss: 0.4491 - val_accuracy: 0.8615
# Epoch 20/200
# 95/95 [==============================] - 1s 6ms/step - loss: 0.0443 - accuracy: 0.9845 - val_loss: 0.4795 - val_accuracy: 0.8536
# Epoch 21/200
# 95/95 [==============================] - 1s 6ms/step - loss: 0.0385 - accuracy: 0.9865 - val_loss: 0.5368 - val_accuracy: 0.8483
# Epoch 22/200
# 95/95 [==============================] - 1s 6ms/step - loss: 0.0375 - accuracy: 0.9871 - val_loss: 0.4922 - val_accuracy: 0.8588
# Epoch 23/200
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0381 - accuracy: 0.9868 - val_loss: 0.5691 - val_accuracy: 0.8483
# Epoch 24/200
# 95/95 [==============================] - 1s 7ms/step - loss: 0.0463 - accuracy: 0.9835 - val_loss: 0.5072 - val_accuracy: 0.8628
# Epoch 25/200
# 95/95 [==============================] - 0s 5ms/step - loss: 0.0278 - accuracy: 0.9901 - val_loss: 0.5144 - val_accuracy: 0.8602
# Epoch 26/200
# 95/95 [==============================] - 0s 4ms/step - loss: 0.0321 - accuracy: 0.9884 - val_loss: 0.5609 - val_accuracy: 0.8575

# %%
test_loss, test_acc = model.evaluate(df_test,test_labels)

print('Test accuracy:', test_acc)
# Out:
# 44/44 [==============================] - 0s 2ms/step - loss: 0.3412 - accuracy: 0.9071
# Test accuracy: 0.9071428775787354
