# %%
import numpy as np
import pandas as pd

# %%
df_train=np.load('/content/drive/MyDrive/only_text/ITA_train_e.npy')

# %%
df_train.shape
# Out:
# (3444, 256)

# %%
train_labels=np.load('/content/drive/MyDrive/only_text/ITA_train_labels.npy')

# %%
train_labels.shape
# Out:
# (3444,)

# %%
df_test=np.load('/content/drive/MyDrive/only_text/ITA_test_e.npy')

# %%
df_test.shape
# Out:
# (1301, 256)

# %%
test_labels=np.load('/content/drive/MyDrive/only_text/ITA_test_labels.npy')

# %%
test_labels.shape
# Out:
# (1301,)

# %%
df_combined = np.concatenate([df_train, df_test], axis=0)


labels_combined = np.concatenate([train_labels, test_labels], axis=0)

# %%
df_combined.shape
# Out:
# (4745, 256)

# %%
labels_combined.shape
# Out:
# (4745,)

# %% [markdown]
# #38%

# %%
np.unique(labels_combined,return_counts=True)
# Out:
# (array([0, 1]), array([2939, 1806]))

# %%
import numpy as np
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# Perform PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(df_combined)


sns.scatterplot(x=pca_result[:, 0], y=pca_result[:, 1], hue=labels_combined)
plt.title('PCA')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(title='Labels')
plt.show()

# %%
 def convert_cluster_labels(cluster_labels, ground_truth_labels):
            unique_clusters = np.unique(cluster_labels)
            num_clusters = len(unique_clusters)
            num_classes = len(np.unique(ground_truth_labels))

            # Create a mapping between cluster labels and ground truth labels
            label_mapping = {}
            for cluster_label in unique_clusters:
                mask = (cluster_labels == cluster_label)
                assigned_labels = ground_truth_labels[mask]
                # print(assigned_labels)
                unique_assigned_labels, counts = np.unique(assigned_labels, return_counts=True)
                # print(unique_assigned_labels)
                # print(counts)
                mapped_label = unique_assigned_labels[np.argmax(counts)]
                label_mapping[cluster_label] = mapped_label

            # Convert cluster labels to ground truth labels
            converted_labels = np.zeros_like(cluster_labels)
            for cluster_label, mapped_label in label_mapping.items():
                converted_labels[cluster_labels == cluster_label] = mapped_label

            return converted_labels

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import classification_report


n_clusters = 2
kmeans = KMeans(n_clusters=n_clusters, random_state=0)
kmeans.fit(df_train)
cluster_labels = kmeans.predict(df_test)

print(classification_report(test_labels, cluster_labels))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.24      0.18      0.20       764
#            1       0.15      0.20      0.17       537
#
#     accuracy                           0.19      1301
#    macro avg       0.19      0.19      0.19      1301
# weighted avg       0.20      0.19      0.19      1301

# %%
np.unique(cluster_labels,return_counts=True)
# Out:
# (array([0, 1], dtype=int32), array([563, 738]))

# %%
new_labels=convert_cluster_labels(cluster_labels,test_labels)

# %%
np.unique(new_labels,return_counts=True)
# Out:
# (array([0, 1], dtype=int32), array([738, 563]))

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import classification_report


n_clusters = 2
kmeans = KMeans(n_clusters=n_clusters, random_state=0)
kmeans.fit(df_train)
cluster_labels = kmeans.predict(df_test)

print(classification_report(test_labels, new_labels))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.85      0.82      0.84       764
#            1       0.76      0.80      0.78       537
#
#     accuracy                           0.81      1301
#    macro avg       0.81      0.81      0.81      1301
# weighted avg       0.82      0.81      0.81      1301

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping

# %%
from keras.optimizers import Adam

model = Sequential([
    Dense(64, activation='relu', input_shape=(256,)),
    BatchNormalization(),
    Dropout(0.3),
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(4, activation='relu'),
    Dense(1, activation='sigmoid')
])


model.compile(optimizer=Adam(learning_rate=1e-3),
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.summary()
# Define callbacks
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                16448
#
#  batch_normalization (Batch  (None, 64)                256
#  Normalization)
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  batch_normalization_1 (Bat  (None, 32)                128
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dense_3 (Dense)             (None, 8)                 136
#
#  dense_4 (Dense)             (None, 4)                 36
#
#  dense_5 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 19617 (76.63 KB)
# Trainable params: 19425 (75.88 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________

# %%
df_train.shape
# Out:
# (3444, 256)

# %%
train_labels.shape
# Out:
# (3444,)

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(df_train,
train_labels,
                    epochs=200,
                    batch_size=32,
                    validation_split=0.2,
                    verbose=1,
                    callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 87/87 [==============================] - 3s 7ms/step - loss: 0.6579 - accuracy: 0.6258 - val_loss: 0.6807 - val_accuracy: 0.6575
# Epoch 2/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.5610 - accuracy: 0.6897 - val_loss: 0.7001 - val_accuracy: 0.4122
# Epoch 3/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.5046 - accuracy: 0.7804 - val_loss: 0.7140 - val_accuracy: 0.3440
# Epoch 4/200
# 87/87 [==============================] - 0s 3ms/step - loss: 0.4809 - accuracy: 0.8142 - val_loss: 0.6954 - val_accuracy: 0.4165
# Epoch 5/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4557 - accuracy: 0.8323 - val_loss: 0.6428 - val_accuracy: 0.5181
# Epoch 6/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4474 - accuracy: 0.8363 - val_loss: 0.6006 - val_accuracy: 0.5951
# Epoch 7/200
# 87/87 [==============================] - 0s 3ms/step - loss: 0.4328 - accuracy: 0.8410 - val_loss: 0.5903 - val_accuracy: 0.6197
# Epoch 8/200
# 87/87 [==============================] - 0s 3ms/step - loss: 0.4306 - accuracy: 0.8417 - val_loss: 0.5493 - val_accuracy: 0.6894
# Epoch 9/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4110 - accuracy: 0.8454 - val_loss: 0.5345 - val_accuracy: 0.6952
# Epoch 10/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3777 - accuracy: 0.8465 - val_loss: 0.5894 - val_accuracy: 0.6662
# Epoch 11/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3514 - accuracy: 0.8472 - val_loss: 0.6495 - val_accuracy: 0.6633
# Epoch 12/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3218 - accuracy: 0.8613 - val_loss: 0.6457 - val_accuracy: 0.6909
# Epoch 13/200
# 87/87 [==============================] - 0s 3ms/step - loss: 0.3364 - accuracy: 0.8519 - val_loss: 0.7131 - val_accuracy: 0.6517
# Epoch 14/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3119 - accuracy: 0.8690 - val_loss: 0.7058 - val_accuracy: 0.6647
# Epoch 15/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3212 - accuracy: 0.8668 - val_loss: 0.5868 - val_accuracy: 0.7242
# Epoch 16/200
# 87/87 [==============================] - 0s 3ms/step - loss: 0.3161 - accuracy: 0.8657 - val_loss: 0.5354 - val_accuracy: 0.7562
# Epoch 17/200
# 87/87 [==============================] - 0s 3ms/step - loss: 0.2980 - accuracy: 0.8708 - val_loss: 0.5226 - val_accuracy: 0.7678
# Epoch 18/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3101 - accuracy: 0.8632 - val_loss: 0.5258 - val_accuracy: 0.7620
# Epoch 19/200
# 87/87 [==============================] - 0s 3ms/step - loss: 0.2862 - accuracy: 0.8722 - val_loss: 0.5073 - val_accuracy: 0.7794
# Epoch 20/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2902 - accuracy: 0.8737 - val_loss: 0.5294 - val_accuracy: 0.7634
# Epoch 21/200
# 87/87 [==============================] - 0s 5ms/step - loss: 0.2707 - accuracy: 0.8828 - val_loss: 0.5190 - val_accuracy: 0.7910
# Epoch 22/200
# 87/87 [==============================] - 0s 5ms/step - loss: 0.2753 - accuracy: 0.8744 - val_loss: 0.5673 - val_accuracy: 0.7576
# Epoch 23/200
# 87/87 [==============================] - 0s 5ms/step - loss: 0.2748 - accuracy: 0.8795 - val_loss: 0.5266 - val_accuracy: 0.7808
# Epoch 24/200
# 87/87 [==============================] - 0s 5ms/step - loss: 0.2639 - accuracy: 0.8842 - val_loss: 0.5258 - val_accuracy: 0.7866
# Epoch 25/200
# 87/87 [==============================] - 0s 5ms/step - loss: 0.2688 - accuracy: 0.8878 - val_loss: 0.5214 - val_accuracy: 0.8026
# Epoch 26/200
# 87/87 [==============================] - 0s 6ms/step - loss: 0.2696 - accuracy: 0.8828 - val_loss: 0.5317 - val_accuracy: 0.7707
# Epoch 27/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.2573 - accuracy: 0.8897 - val_loss: 0.5122 - val_accuracy: 0.8099
# Epoch 28/200
# 87/87 [==============================] - 0s 6ms/step - loss: 0.2588 - accuracy: 0.8918 - val_loss: 0.5179 - val_accuracy: 0.7939
# Epoch 29/200
# 87/87 [==============================] - 0s 5ms/step - loss: 0.2481 - accuracy: 0.8922 - val_loss: 0.5146 - val_accuracy: 0.7983

# %%
test_loss, test_acc = model.evaluate(df_test,test_labels)

print('Test accuracy:', test_acc)
# Out:
# 41/41 [==============================] - 0s 2ms/step - loss: 0.3240 - accuracy: 0.8778
# Test accuracy: 0.8777863383293152
