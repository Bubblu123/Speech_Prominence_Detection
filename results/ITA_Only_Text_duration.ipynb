# %%
import numpy as np
import pandas as pd

# %%
df_train=np.load('/content/drive/MyDrive/only_text/ITA_train_d.npy')

# %%
df_train.shape
# Out:
# (3444, 256)

# %%
train_labels=np.load('/content/drive/MyDrive/only_text/ITA_train_labels.npy')

# %%
train_labels.shape
# Out:
# (3444,)

# %%
df_test=np.load('/content/drive/MyDrive/only_text/ITA_test_d.npy')

# %%
df_test.shape
# Out:
# (1301, 256)

# %%
test_labels=np.load('/content/drive/MyDrive/only_text/ITA_test_labels.npy')

# %%
test_labels.shape
# Out:
# (1301,)

# %%
df_combined = np.concatenate([df_train, df_test], axis=0)


labels_combined = np.concatenate([train_labels, test_labels], axis=0)

# %%
df_combined.shape
# Out:
# (4745, 256)

# %%
labels_combined.shape
# Out:
# (4745,)

# %% [markdown]
# #38%

# %%
np.unique(labels_combined,return_counts=True)
# Out:
# (array([0, 1]), array([2939, 1806]))

# %%
import numpy as np
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# Perform PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(df_combined)


sns.scatterplot(x=pca_result[:, 0], y=pca_result[:, 1], hue=labels_combined)
plt.title('PCA')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(title='Labels')
plt.show()

# %%
 def convert_cluster_labels(cluster_labels, ground_truth_labels):
            unique_clusters = np.unique(cluster_labels)
            num_clusters = len(unique_clusters)
            num_classes = len(np.unique(ground_truth_labels))

            # Create a mapping between cluster labels and ground truth labels
            label_mapping = {}
            for cluster_label in unique_clusters:
                mask = (cluster_labels == cluster_label)
                assigned_labels = ground_truth_labels[mask]
                # print(assigned_labels)
                unique_assigned_labels, counts = np.unique(assigned_labels, return_counts=True)
                # print(unique_assigned_labels)
                # print(counts)
                mapped_label = unique_assigned_labels[np.argmax(counts)]
                label_mapping[cluster_label] = mapped_label

            # Convert cluster labels to ground truth labels
            converted_labels = np.zeros_like(cluster_labels)
            for cluster_label, mapped_label in label_mapping.items():
                converted_labels[cluster_labels == cluster_label] = mapped_label

            return converted_labels

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import classification_report


n_clusters = 2
kmeans = KMeans(n_clusters=n_clusters, random_state=0)
kmeans.fit(df_train)
cluster_labels = kmeans.predict(df_test)

print(classification_report(test_labels, cluster_labels))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.15      0.11      0.13       764
#            1       0.06      0.09      0.07       537
#
#     accuracy                           0.10      1301
#    macro avg       0.11      0.10      0.10      1301
# weighted avg       0.11      0.10      0.11      1301

# %%
np.unique(cluster_labels,return_counts=True)
# Out:
# (array([0, 1], dtype=int32), array([575, 726]))

# %%
new_labels=convert_cluster_labels(cluster_labels,test_labels)

# %%
np.unique(new_labels,return_counts=True)
# Out:
# (array([0, 1], dtype=int32), array([726, 575]))

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import classification_report


n_clusters = 2
kmeans = KMeans(n_clusters=n_clusters, random_state=0)
kmeans.fit(df_train)
cluster_labels = kmeans.predict(df_test)

print(classification_report(test_labels, new_labels))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.91       764
#            1       0.85      0.91      0.88       537
#
#     accuracy                           0.90      1301
#    macro avg       0.89      0.90      0.90      1301
# weighted avg       0.90      0.90      0.90      1301

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping

# %%
from keras.optimizers import Adam

model = Sequential([
    Dense(64, activation='relu', input_shape=(256,)),
    BatchNormalization(),
    Dropout(0.3),
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(4, activation='relu'),
    Dense(1, activation='sigmoid')
])


model.compile(optimizer=Adam(learning_rate=1e-3),
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.summary()
# Define callbacks
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                16448
#
#  batch_normalization (Batch  (None, 64)                256
#  Normalization)
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  batch_normalization_1 (Bat  (None, 32)                128
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dense_3 (Dense)             (None, 8)                 136
#
#  dense_4 (Dense)             (None, 4)                 36
#
#  dense_5 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 19617 (76.63 KB)
# Trainable params: 19425 (75.88 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________

# %%
df_train.shape
# Out:
# (3444, 256)

# %%
train_labels.shape
# Out:
# (3444,)

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(df_train,
train_labels,
                    epochs=200,
                    batch_size=32,
                    validation_split=0.2,
                    verbose=1,
                    callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 87/87 [==============================] - 3s 7ms/step - loss: 0.6701 - accuracy: 0.5684 - val_loss: 0.7008 - val_accuracy: 0.6589
# Epoch 2/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.4679 - accuracy: 0.7938 - val_loss: 3.3537 - val_accuracy: 0.6589
# Epoch 3/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.3141 - accuracy: 0.8661 - val_loss: 3.3176 - val_accuracy: 0.6589
# Epoch 4/200
# 87/87 [==============================] - 0s 5ms/step - loss: 0.2677 - accuracy: 0.8857 - val_loss: 2.0670 - val_accuracy: 0.6589
# Epoch 5/200
# 87/87 [==============================] - 0s 5ms/step - loss: 0.2413 - accuracy: 0.8987 - val_loss: 1.2640 - val_accuracy: 0.6894
# Epoch 6/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2270 - accuracy: 0.9096 - val_loss: 0.7660 - val_accuracy: 0.7678
# Epoch 7/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2283 - accuracy: 0.9053 - val_loss: 0.5723 - val_accuracy: 0.8157
# Epoch 8/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2101 - accuracy: 0.9132 - val_loss: 0.4696 - val_accuracy: 0.8433
# Epoch 9/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2115 - accuracy: 0.9154 - val_loss: 0.3914 - val_accuracy: 0.8505
# Epoch 10/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2173 - accuracy: 0.9122 - val_loss: 0.3428 - val_accuracy: 0.8694
# Epoch 11/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2078 - accuracy: 0.9122 - val_loss: 0.3186 - val_accuracy: 0.8781
# Epoch 12/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2152 - accuracy: 0.9114 - val_loss: 0.3338 - val_accuracy: 0.8723
# Epoch 13/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.2075 - accuracy: 0.9172 - val_loss: 0.3568 - val_accuracy: 0.8737
# Epoch 14/200
# 87/87 [==============================] - 0s 5ms/step - loss: 0.1926 - accuracy: 0.9187 - val_loss: 0.3123 - val_accuracy: 0.8824
# Epoch 15/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.1950 - accuracy: 0.9201 - val_loss: 0.2882 - val_accuracy: 0.8766
# Epoch 16/200
# 87/87 [==============================] - 1s 7ms/step - loss: 0.1795 - accuracy: 0.9303 - val_loss: 0.2871 - val_accuracy: 0.8839
# Epoch 17/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.1876 - accuracy: 0.9260 - val_loss: 0.2799 - val_accuracy: 0.8882
# Epoch 18/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.1864 - accuracy: 0.9270 - val_loss: 0.2863 - val_accuracy: 0.8810
# Epoch 19/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.1797 - accuracy: 0.9321 - val_loss: 0.2785 - val_accuracy: 0.8853
# Epoch 20/200
# 87/87 [==============================] - 1s 8ms/step - loss: 0.1770 - accuracy: 0.9260 - val_loss: 0.2857 - val_accuracy: 0.8882
# Epoch 21/200
# 87/87 [==============================] - 1s 7ms/step - loss: 0.1695 - accuracy: 0.9328 - val_loss: 0.2762 - val_accuracy: 0.8897
# Epoch 22/200
# 87/87 [==============================] - 1s 6ms/step - loss: 0.1698 - accuracy: 0.9354 - val_loss: 0.2860 - val_accuracy: 0.8853
# Epoch 23/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.1650 - accuracy: 0.9314 - val_loss: 0.2881 - val_accuracy: 0.8911
# Epoch 24/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.1660 - accuracy: 0.9325 - val_loss: 0.3086 - val_accuracy: 0.8810
# Epoch 25/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.1578 - accuracy: 0.9408 - val_loss: 0.2990 - val_accuracy: 0.8868
# Epoch 26/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.1487 - accuracy: 0.9416 - val_loss: 0.3125 - val_accuracy: 0.8853
# Epoch 27/200
# 87/87 [==============================] - 0s 5ms/step - loss: 0.1493 - accuracy: 0.9434 - val_loss: 0.3097 - val_accuracy: 0.8824
# Epoch 28/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.1363 - accuracy: 0.9470 - val_loss: 0.3051 - val_accuracy: 0.8810
# Epoch 29/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.1422 - accuracy: 0.9448 - val_loss: 0.3096 - val_accuracy: 0.8824
# Epoch 30/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.1426 - accuracy: 0.9466 - val_loss: 0.3198 - val_accuracy: 0.8781
# Epoch 31/200
# 87/87 [==============================] - 0s 4ms/step - loss: 0.1391 - accuracy: 0.9456 - val_loss: 0.3323 - val_accuracy: 0.8868

# %%
test_loss, test_acc = model.evaluate(df_test,test_labels)

print('Test accuracy:', test_acc)
# Out:
# 41/41 [==============================] - 0s 2ms/step - loss: 0.2254 - accuracy: 0.9231
# Test accuracy: 0.9231360554695129
